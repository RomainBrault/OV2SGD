# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pyov2sgd as orff
import operalib as ovk
import numpy as np
import time
import ad
from sklearn.kernel_approximation import RBFSampler
from sklearn.grid_search import GridSearchCV
import operalib as ovk
from autograd import elementwise_grad
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt
from scipy.spatial.distance import pdist
from sklearn.ensemble import ExtraTreesRegressor

# %%
import autograd.numpy as np   # Thinly-wrapped version of Numpy
d = 2
n = int(np.sqrt(1000)) ** 2

# np.random.seed(0)

D = 2000
amp = 1.
W = amp * np.random.randn(d, D)
coefs = np.random.randn(2 * D, 1)

Xg = 2 * np.random.rand(n, d) - 1

def f(X):
    Z = np.dot(X, W)
    return np.dot(np.hstack((np.cos(Z), np.sin(Z))), coefs)


g = elementwise_grad(f)
yg = g(Xg)

X, Xtest, y, ytest = train_test_split(Xg, yg)
y = y + .5 * y.std() * np.random.randn(y.shape[0], y.shape[1])
import numpy as np

# %%
plt.quiver(Xg[:, 0], Xg[:, 1], yg[:, 0], yg[:,1])

# %%
est = ovk.ORFFRidge(ovkernel='DGauss', A = np.array([[1000, 0], [0, 1]]), gamma=1., lbda=10.)
est.fit(Xg, yg)
yt = est.predict(Xg)

# %%
plt.quiver(Xg[:, 0], Xg[:, 1], yt[:, 0], yt[:,1])

# %%
np.linalg.norm(est.coefs_.reshape((-1, 2)), axis=0)
# Out:
# array([ 14.54178609,  48.79225677])

# %%
print(est.phix_ * est.coefs_)
# Out:
# [ 40.66386644  25.9201805    8.55803611 ...,  36.39057216 -95.73327787
#  -25.13362453]

# %%
est.phix_.shape
# Out:
# (1922, 1000)

# %%
est.coefs_.shape
# Out:
# (1000,)

# %%
ph = est.linop_.r

# %%
np.dot(est.linop_.B_, est.linop_.B_.T)
# Out:
# array([[ 2.]])

# %%
ph
# Out:
# 1
